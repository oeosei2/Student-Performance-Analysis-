# %% [markdown]
# #  STUDENTS PERFORMANCE DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.skew()
# Out:
# math score      -0.278935
# reading score   -0.259105
# writing score   -0.289444
# dtype: float64

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['gender'].value_counts().plot.bar(color=['b','g'])
plt.title('Categories of Gender')
plt.show()

# %%
data['gender'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
data['parental level of education'].value_counts().plot.bar()
plt.title('Distribution of parental level of education')
plt.show()

# %%
data['lunch'].value_counts().plot.pie()

# %%
plt.hist(data['math score'],bins=25)
plt.show()

# %%
bins=[10,20,30,40,50,60,70,80]
plt.hist(data['reading score'],bins=20)
plt.show()

# %%
plt.hist(data['writing score'],bins=25)
plt.show()

# %%
bins=[0,40,50,60,100]
math=pd.cut(data['math score'],bins=bins)
math.value_counts()
# Out:
# (60, 100]    661
# (50, 60]     189
# (40, 50]     100
# (0, 40]       49
# Name: math score, dtype: int64

# %%
sns.countplot(math,hue=data['gender'])
plt.xticks(rotation=90)
plt.show()

# %%
bins=[0,40,60,80,100]
writing=pd.cut(data['writing score'],bins=bins)
writing.value_counts()
# Out:
# (60, 80]     491
# (40, 60]     266
# (80, 100]    208
# (0, 40]       35
# Name: writing score, dtype: int64

# %%
sns.countplot(writing,hue=data['gender'])
plt.show()

# %%
bins=[0,40,60,80,100]
reading=pd.cut(data['reading score'],bins=bins)
reading.value_counts()
# Out:
# (60, 80]     490
# (40, 60]     248
# (80, 100]    235
# (0, 40]       27
# Name: reading score, dtype: int64

# %%
sns.countplot(reading,hue=data['gender'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(reading,hue=data['race/ethnicity'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(writing,hue=data['race/ethnicity'])
plt.show()

# %%
sns.countplot(math,hue=data['race/ethnicity'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(math,hue=data['parental level of education'])
plt.show()

# %%
data['test preparation course'].value_counts().plot.bar(color=['r','black'])
plt.title('Distribution of test Preparation course')

# %%
plt.boxplot(data['writing score'])
plt.show()

# %%
sns.pairplot(data)

# %%
plt.boxplot(data['math score'])
plt.show()

# %%
sns.distplot(data['writing score'])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Corralation Between All Variables ')
sns.heatmap(data.corr(),annot=True)
plt.show()
